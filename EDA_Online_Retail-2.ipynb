# %% [markdown]
# # Exploratory Data Analysis (EDA) — Online Retail Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('online_retail.csv')
df.head()
# Out:
#    InvoiceNo  StockCode        Description  Quantity InvoiceDate  UnitPrice  \
# 0      12732        777       Cookies Pack        17  2024-01-12       4.63
# 1      19845        271           Gift Box        13  2024-06-08      23.07
# 2      13264        823          Candy Bag         5  2024-05-18       3.40
# 3      14859        956  Premium Chocolate        17  2024-01-21      12.80
# 4      19225        682          Candy Bag        15  2024-04-10      12.18
#
#    CustomerID       Country
# 0        1040  Saudi Arabia
# 1        1086         Qatar
# 2        1052        Kuwait
# 3        1043         Qatar
# 4        1065  Saudi Arabia

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    500 non-null    int64
#  1   StockCode    500 non-null    int64
#  2   Description  500 non-null    object
#  3   Quantity     500 non-null    int64
#  4   InvoiceDate  500 non-null    object
#  5   UnitPrice    500 non-null    float64
#  6   CustomerID   500 non-null    int64
#  7   Country      500 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 31.4+ KB
#           InvoiceNo   StockCode    Quantity   UnitPrice   CustomerID
# count    500.000000  500.000000  500.000000  500.000000   500.000000
# mean   15015.280000  549.526000   10.208000   13.324560  1047.986000
# std     2814.347548  255.600478    5.304433    6.804919    28.197376
# min    10025.000000  100.000000    1.000000    1.500000  1000.000000
# 25%    12659.750000  325.000000    6.000000    7.660000  1025.750000
# 50%    15054.500000  548.000000   10.000000   13.590000  1048.000000
# 75%    17408.000000  762.500000   15.000000   18.662500  1071.250000
# max    19987.000000  995.000000   19.000000   24.960000  1099.000000

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['TotalAmount'] = df['Quantity'] * df['UnitPrice']
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# TotalAmount    0
# dtype: int64

# %%
sns.histplot(df['TotalAmount'], kde=True)
plt.show()

# %%
df.groupby(df['InvoiceDate'].dt.to_period('M'))['TotalAmount'].sum().plot()
plt.show()

# %%
df.groupby('Country')['TotalAmount'].sum().sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
sns.heatmap(df[['Quantity','UnitPrice','TotalAmount']].corr(), annot=True)
plt.show()

# %% [markdown]
# ## Conclusion
# - Dataset cleaned and explored successfully.
# - Sales distribution is right‑skewed.
# - Certain countries contribute more revenue.
# - Quantity strongly impacts total sales.
